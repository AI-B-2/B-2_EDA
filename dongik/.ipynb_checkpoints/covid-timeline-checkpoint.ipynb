# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import plotly.express as px
import plotly.graph_objs as go
# import plotly.figure_factory as ff
from plotly.subplots import make_subplots
# for offline ploting
from plotly.offline import plot, iplot, init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('./full_grouped.csv')
data
# Out:
#              Date      Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0      2020-01-22         Afghanistan          0       0          0       0
# 1      2020-01-22             Albania          0       0          0       0
# 2      2020-01-22             Algeria          0       0          0       0
# 3      2020-01-22             Andorra          0       0          0       0
# 4      2020-01-22              Angola          0       0          0       0
# ...           ...                 ...        ...     ...        ...     ...
# 35151  2020-07-27  West Bank and Gaza      10621      78       3752    6791
# 35152  2020-07-27      Western Sahara         10       1          8       1
# 35153  2020-07-27               Yemen       1691     483        833     375
# 35154  2020-07-27              Zambia       4552     140       2815    1597
# 35155  2020-07-27            Zimbabwe       2704      36        542    2126
#
#        New cases  New deaths  New recovered             WHO Region
# 0              0           0              0  Eastern Mediterranean
# 1              0           0              0                 Europe
# 2              0           0              0                 Africa
# 3              0           0              0                 Europe
# 4              0           0              0                 Africa
# ...          ...         ...            ...                    ...
# 35151        152           2              0  Eastern Mediterranean
# 35152          0           0              0                 Africa
# 35153         10           4             36  Eastern Mediterranean
# 35154         71           1            465                 Africa
# 35155        192           2             24                 Africa
#
# [35156 rows x 10 columns]

# %%
data_europe = data[data['WHO Region']=='Europe']
data_europe
# Out:
#              Date  Country/Region  Confirmed  Deaths  Recovered  Active  \
# 1      2020-01-22         Albania          0       0          0       0
# 3      2020-01-22         Andorra          0       0          0       0
# 7      2020-01-22         Armenia          0       0          0       0
# 9      2020-01-22         Austria          0       0          0       0
# 10     2020-01-22      Azerbaijan          0       0          0       0
# ...           ...             ...        ...     ...        ...     ...
# 35134  2020-07-27      Tajikistan       7235      60       6028    1147
# 35141  2020-07-27          Turkey     227019    5630     210469   10920
# 35144  2020-07-27         Ukraine      67096    1636      37202   28258
# 35146  2020-07-27  United Kingdom     301708   45844       1437  254427
# 35148  2020-07-27      Uzbekistan      21209     121      11674    9414
#
#        New cases  New deaths  New recovered WHO Region
# 1              0           0              0     Europe
# 3              0           0              0     Europe
# 7              0           0              0     Europe
# 9              0           0              0     Europe
# 10             0           0              0     Europe
# ...          ...         ...            ...        ...
# 35134         43           1             58     Europe
# 35141        919          17            982     Europe
# 35144        835          11            317     Europe
# 35146        688           7              3     Europe
# 35148        678           5            569     Europe
#
# [10528 rows x 10 columns]

# %%
data_europe.groupby('Date').sum()
# Out:
# Date
# 2020-01-22        0
# 2020-01-23        0
# 2020-01-24        2
# 2020-01-25        1
# 2020-01-26        0
#               ...
# 2020-07-23    27307
# 2020-07-24    23011
# 2020-07-25    19335
# 2020-07-26    18182
# 2020-07-27    22294
# Name: New cases, Length: 188, dtype: int64

# %%
data_europe = data_europe.groupby('Date').sum()['New cases']
data_europe.plot()
plt.title('Europe Timeline')
# Out:
# Text(0.5, 1.0, 'Europe Timeline')

# %%
data_africa = data[data['WHO Region']=='Africa']
data_africa.groupby('Date').sum()['New cases'].plot()
plt.title('Africa Timeline')
# Out:
# Text(0.5, 1.0, 'Africa Timeline')

# %%
data_em = data[data['WHO Region']=='Eastern Mediterranean']
data_em.groupby('Date').sum()['New cases'].plot()
plt.title('Eastern Mediterranean Timeline')
plt.show()

# %%
data_am = data[data['WHO Region']=='Americas']
data_am.groupby('Date').sum()['New cases'].plot()
plt.title('Americas Timeline')
plt.show()

# %%
data_wp = data[data['WHO Region']=='Western Pacific']
data_wp.groupby('Date').sum()['New cases'].plot()
plt.title('Western Pacific Timeline')
plt.xticks(rotation='vertical')
plt.ylabel('New Cases')
plt.show()

# x = [date for date, df in data_wp.groupby('Date')]
# ax = ['Jan.', 'Feb.', 'Mar.', 'Apr.', 'May.', 'Jun.','July.']
# plt.plot(x, data_wp.groupby('Date').sum()['New cases'])
# plt.xlabel(ax, rotation='vertical')
# plt.show()

# %%
data_sea = data[data['WHO Region']=='South-East Asia']
data_sea.groupby('Date').sum()['New cases'].plot()
plt.title('South-East Asia Timeline')
plt.xticks(rotation='vertical')
plt.ylabel('New Cases')
plt.show()

# %%
data_europe.groupby('Date').sum()['New cases'].plot()
data_africa.groupby('Date').sum()['New cases'].plot()
data_em.groupby('Date').sum()['New cases'].plot()
data_am.groupby('Date').sum()['New cases'].plot()
data_wp.groupby('Date').sum()['New cases'].plot()
data_sea.groupby('Date').sum()['New cases'].plot()

plt.xticks(rotation='vertical')
plt.ylabel('New Cases')
plt.legend(['Europe', 'Africa', 'Eastern Mediterranean','Americas', 'Western Pacific', 'South-East Asia'])
plt.show()

# %%
import plotly.express as px

# df = px.data.gapminder().query("continent=='Oceania'")
# fig = px.line(df, x="year", y="lifeExp", color='country')
# fig.show()


trace2 = go.Scatter(x = data_europe['Date'], y = data_europe['New cases'], mode = 'lines', name = 'lines')
iplot(trace2)
# Out:
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-36-a231b7aaebc4> in <module>
#       7
#       8 trace2 = go.Scatter(x = data_europe['Date'], y = data_europe['New cases'], mode = 'lines', name = 'lines')
# ----> 9 iplot(trace2)
#
# /usr/local/lib/python3.9/site-packages/plotly/offline/offline.py in iplot(figure_or_data, show_link, link_text, validate, image, filename, image_width, image_height, config, auto_play, animation_opts)
#     382
#     383     # Get figure
# --> 384     figure = tools.return_figure_from_figure_or_data(figure_or_data, validate)
#     385
#     386     # Handle image request
#
# /usr/local/lib/python3.9/site-packages/plotly/tools.py in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#     542         validated = True
#     543     else:
# --> 544         raise exceptions.PlotlyError(
#     545             "The `figure_or_data` positional "
#     546             "argument must be "
#
# PlotlyError: The `figure_or_data` positional argument must be `dict`-like, `list`-like, or an instance of plotly.graph_objs.Figure

# %%
data_am
# Out:
#              Date       Country/Region  Confirmed  Deaths  Recovered   Active  \
# 5      2020-01-22  Antigua and Barbuda          0       0          0        0
# 6      2020-01-22            Argentina          0       0          0        0
# 11     2020-01-22              Bahamas          0       0          0        0
# 14     2020-01-22             Barbados          0       0          0        0
# 17     2020-01-22               Belize          0       0          0        0
# ...           ...                  ...        ...     ...        ...      ...
# 35129  2020-07-27             Suriname       1483      24        925      534
# 35139  2020-07-27  Trinidad and Tobago        148       8        128       12
# 35142  2020-07-27                   US    4290259  148011    1325804  2816444
# 35147  2020-07-27              Uruguay       1202      35        951      216
# 35149  2020-07-27            Venezuela      15988     146       9959     5883
#
#        New cases  New deaths  New recovered WHO Region
# 5              0           0              0   Americas
# 6              0           0              0   Americas
# 11             0           0              0   Americas
# 14             0           0              0   Americas
# 17             0           0              0   Americas
# ...          ...         ...            ...        ...
# 35129         44           1             35   Americas
# 35139          1           0              0   Americas
# 35142      56336        1076          27941   Americas
# 35147         10           1              3   Americas
# 35149        525           4            213   Americas
#
# [6580 rows x 10 columns]

# %%
def plot_map(df, col, pal):
    df = df[df[col]>0]
    fig = px.choropleth(df, locations="Country", locationmode='country names',
                  color=col, hover_name="Country",
                  title=col, hover_data=[col], color_continuous_scale=pal)
#     fig.update_layout(coloraxis_showscale=False)
    fig.show()

# %%
data_map = data[['Date', 'New cases', 'WHO Region']]
data_map
# Out:
#              Date  New cases             WHO Region
# 0      2020-01-22          0  Eastern Mediterranean
# 1      2020-01-22          0                 Europe
# 2      2020-01-22          0                 Africa
# 3      2020-01-22          0                 Europe
# 4      2020-01-22          0                 Africa
# ...           ...        ...                    ...
# 35151  2020-07-27        152  Eastern Mediterranean
# 35152  2020-07-27          0                 Africa
# 35153  2020-07-27         10  Eastern Mediterranean
# 35154  2020-07-27         71                 Africa
# 35155  2020-07-27        192                 Africa
#
# [35156 rows x 3 columns]

# %%
def plot_map(df, col, pal):
    df = data_map
    fig = px.choropleth(df, locations="WHO Region", locationmode='country names',
                  color=col, hover_name="Country",
                  title=col, hover_data=[col], color_continuous_scale=pal)
#     fig.update_layout(coloraxis_showscale=False)
    fig.show()

# %%
data['WHO Region'].unique()
# Out:
# array(['Eastern Mediterranean', 'Europe', 'Africa', 'Americas',
#        'Western Pacific', 'South-East Asia'], dtype=object)

# %%
data['Date'] = pd.to_datetime(data['Date'])
data
# Out:
#             Date      Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0     2020-01-22         Afghanistan          0       0          0       0
# 1     2020-01-22             Albania          0       0          0       0
# 2     2020-01-22             Algeria          0       0          0       0
# 3     2020-01-22             Andorra          0       0          0       0
# 4     2020-01-22              Angola          0       0          0       0
# ...          ...                 ...        ...     ...        ...     ...
# 35151 2020-07-27  West Bank and Gaza      10621      78       3752    6791
# 35152 2020-07-27      Western Sahara         10       1          8       1
# 35153 2020-07-27               Yemen       1691     483        833     375
# 35154 2020-07-27              Zambia       4552     140       2815    1597
# 35155 2020-07-27            Zimbabwe       2704      36        542    2126
#
#        New cases  New deaths  New recovered             WHO Region
# 0              0           0              0  Eastern Mediterranean
# 1              0           0              0                 Europe
# 2              0           0              0                 Africa
# 3              0           0              0                 Europe
# 4              0           0              0                 Africa
# ...          ...         ...            ...                    ...
# 35151        152           2              0  Eastern Mediterranean
# 35152          0           0              0                 Africa
# 35153         10           4             36  Eastern Mediterranean
# 35154         71           1            465                 Africa
# 35155        192           2             24                 Africa
#
# [35156 rows x 10 columns]

# %%
data_by_time = data.groupby(['Date', 'WHO Region']).count()
data_by_time
# Out:
#                                   Country/Region  Confirmed  Deaths  \
# Date       WHO Region
# 2020-01-22 Africa                             48         48      48
#            Americas                           35         35      35
#            Eastern Mediterranean              22         22      22
#            Europe                             56         56      56
#            South-East Asia                    10         10      10
# ...                                          ...        ...     ...
# 2020-07-27 Americas                           35         35      35
#            Eastern Mediterranean              22         22      22
#            Europe                             56         56      56
#            South-East Asia                    10         10      10
#            Western Pacific                    16         16      16
#
#                                   Recovered  Active  New cases  New deaths  \
# Date       WHO Region
# 2020-01-22 Africa                        48      48         48          48
#            Americas                      35      35         35          35
#            Eastern Mediterranean         22      22         22          22
#            Europe                        56      56         56          56
#            South-East Asia               10      10         10          10
# ...                                     ...     ...        ...         ...
# 2020-07-27 Americas                      35      35         35          35
#            Eastern Mediterranean         22      22         22          22
#            Europe                        56      56         56          56
#            South-East Asia               10      10         10          10
#            Western Pacific               16      16         16          16
#
#                                   New recovered
# Date       WHO Region
# 2020-01-22 Africa                            48
#            Americas                          35
#            Eastern Mediterranean             22
#            Europe                            56
#            South-East Asia                   10
# ...                                         ...
# 2020-07-27 Americas                          35
#            Eastern Mediterranean             22
#            Europe                            56
#            South-East Asia                   10
#            Western Pacific                   16
#
# [1128 rows x 8 columns]

# %%
data.groupby(['Date', 'WHO Region']).count()[data.groupby(['Date', 'WHO Region']).count()['WHO Region']==Africa]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WHO Region'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-0a948d40228f> in <module>
# ----> 1 data.groupby(['Date', 'WHO Region']).count()[data.groupby(['Date', 'WHO Region']).count()['WHO Region']==Africa]
#
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'WHO Region'

# %%
data_by_time['New cases']
# Out:
# Date        WHO Region
# 2020-01-22  Africa                   48
#             Americas                 35
#             Eastern Mediterranean    22
#             Europe                   56
#             South-East Asia          10
#                                      ..
# 2020-07-27  Americas                 35
#             Eastern Mediterranean    22
#             Europe                   56
#             South-East Asia          10
#             Western Pacific          16
# Name: New cases, Length: 1128, dtype: int64

# %%
sns.
